# %% [markdown]
# <a href="https://colab.research.google.com/github/eduseiti/ia368v_dd_final/blob/master/test_colbertx_part_00_index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys

# %%
IN_COLAB='google.colab' in sys.modules

# %%
if IN_COLAB:
    from google.colab import drive

    WORKING_FOLDER="/content/drive/MyDrive/unicamp/ia368v_dd/trabalho_final_UNICAMP-IR"

    drive.mount('/content/drive', force_remount=True)

    os.chdir(WORKING_FOLDER)

    # !pip install transformers -q
    # !pip install mlflow -q
    # !pip install ujson -q
    # !pip install faiss-gpu -q
    # !pip install SentencePiece -q
    # !pip install faiss-gpu -q

    if not os.path.exists("ColBERT-X"):
        # !git clone https://github.com/hltcoe/ColBERT-X.git

    PYTHON="python3"
else:
    WORKING_FOLDER="/mnt/0060f889-4c27-409b-b0de-47f5427515e3/unicamp/ia368v_dd/trabalho_final/"

    PỲTHON="python3.8"
# Out:
# Mounted at /content/drive
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 66.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 28.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 98.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 80.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 80.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.5/83.5 kB 11.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 22.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 25.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.1/148.1 kB 19.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 10.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 9.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.6 MB/s eta 0:00:00
#   Building wheel for databricks-cli (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 21.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 15.0 MB/s eta 0:00:00

# %%
CLUEWEB22_FOLDER="clueweb22-pt_10M_sample"

CORPUS_PART_INDEX="clueweb22-pt_10M_sample_part_00_index"

QUERIES_FILE="queries_validation.tsv"

# %%
os.chdir("ColBERT-X")

# %% [markdown]
# ## Execute the retrieval over 3 parts at a time to avoid exhausting the CPU RAM

# %%
# !python3 -m xlmr_colbert.retrieve --similarity l2 --dim 48 --query_maxlen 32 \
	--index_root ../{CLUEWEB22_FOLDER} --index_name {CORPUS_PART_INDEX} --faiss_name ivfpq.262144.faiss --part-range 0..3 --log_scores \
	--retrieve_only --queries ../{QUERIES_FILE} \
	--amp --checkpoint ../colbertx_experiments/mMSMARCO-pt_048_dim/train.py/fine_tune_025/checkpoints/colbert-20000.dnn
# Out:
# 2023-06-21 23:52:29.438816: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-06-21 23:52:29.494509: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-21 23:52:30.536170: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
#
# [Jun 21, 23:52:31] #> Creating directory /content/drive/MyDrive/unicamp/ia368v_dd/trabalho_final_UNICAMP-IR/ColBERT-X/experiments/dirty/retrieve.py/2023-06-21_23.52.31
#
#
#
#
# [Jun 21, 23:52:32] #> Creating directory /content/drive/MyDrive/unicamp/ia368v_dd/trabalho_final_UNICAMP-IR/ColBERT-X/experiments/dirty/retrieve.py/2023-06-21_23.52.31/logs/
#
#
# [Jun 21, 23:52:32] {'root': 'experiments', 'experiment': 'dirty', 'run': '2023-06-21_23.52.31', 'rank': -1, 'similarity': 'l2', 'dim': 48, 'query_maxlen': 32, 'doc_maxlen': 180, 'mask_punctuation': False, 'checkpoint': '../colbertx_experiments/mMSMARCO-pt_048_dim/train.py/fine_tune_025/checkpoints/colbert-20000.dnn', 'bsize': 128, 'amp': True, 'queries': '../queries_validation.tsv', 'collection': None, 'qrels': None, 'index_root': '../clueweb22-pt_10M_sample', 'index_name': 'clueweb22-pt_10M_sample_part_00_index', 'partitions': None, 'nprobe': 10, 'retrieve_only': True, 'faiss_name': 'ivfpq.262144.faiss', 'faiss_depth': 1024, 'part_range': '0..3', 'batch': False, 'depth': 1000, 'log_scores': True}
#
# XLMRobertaConfig {
#   "_name_or_path": "xlm-roberta-large",
#   "architectures": [
#     "XLMRobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.30.2",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#
# Some weights of the model checkpoint at xlm-roberta-large were not used when initializing ColBERT: ['lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing ColBERT from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ColBERT from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ColBERT were not initialized from the model checkpoint at xlm-roberta-large and are newly initialized: ['linear.weight', 'roberta.embeddings.position_ids']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [Jun 21, 23:52:42] #> Loading model checkpoint.
# [Jun 21, 23:52:42] #> Loading checkpoint ../colbertx_experiments/mMSMARCO-pt_048_dim/train.py/fine_tune_025/checkpoints/colbert-20000.dnn ..
# [Jun 21, 23:53:03] #> checkpoint['epoch'] = 0
# [Jun 21, 23:53:03] #> checkpoint['batch'] = 20000
# [Jun 21, 23:53:03] [WARNING] 	 Got checkpoint['arguments']['doc_maxlen'] != args.doc_maxlen (i.e., 480 != 180)
# {
#     "root": "..\/colbertx_experiments\/",
#     "experiment": "mMSMARCO-pt_048_dim",
#     "run": "fine_tune_025",
#     "rank": -1,
#     "similarity": "l2",
#     "dim": 48,
#     "query_maxlen": 32,
#     "doc_maxlen": 480,
#     "mask_punctuation": false,
#     "resume": false,
#     "resume_optimizer": false,
#     "checkpoint": "..\/colbertx_experiments\/mMSMARCO-pt_048_dim\/train.py\/fine_tune_012\/checkpoints\/colbert-20000.dnn",
#     "lr": 3e-6,
#     "maxsteps": 20000,
#     "bsize": 12,
#     "accumsteps": 1,
#     "amp": true,
#     "base_model": "xlm-roberta-large",
#     "triples": "..\/mMARCO_triplets_025.tsv",
#     "queries": null,
#     "collection": null
# }
#
#
# [Jun 21, 23:53:05] #> Loading the queries from ../queries_validation.tsv ...
# [Jun 21, 23:53:05] #> Got 100 queries. All QIDs are unique.
#
# [Jun 21, 23:53:07] #> Loading the FAISS index from ../clueweb22-pt_10M_sample/clueweb22-pt_10M_sample_part_00_index/ivfpq.262144.faiss ..
# [Jun 21, 23:55:07] #> Building the emb2pid mapping..
# self.relative_range = range(0, 629145)
# [Jun 21, 23:55:22] len(self.emb2pid) = 580720308
# [Jun 21, 23:55:28] tensor.size() =  torch.Size([182325872, 48])
# [Jun 21, 23:55:28] |> Loading ../clueweb22-pt_10M_sample/clueweb22-pt_10M_sample_part_00_index/0.pt ...
# [Jun 21, 23:56:09] |> Loading ../clueweb22-pt_10M_sample/clueweb22-pt_10M_sample_part_00_index/1.pt ...
# [Jun 21, 23:57:09] |> Loading ../clueweb22-pt_10M_sample/clueweb22-pt_10M_sample_part_00_index/2.pt ...
# [Jun 21, 23:58:01] #> Using strides [401, 480]..
# [Jun 21, 23:58:02] #> Logging ranked lists to /content/drive/MyDrive/unicamp/ia368v_dd/trabalho_final_UNICAMP-IR/ColBERT-X/experiments/dirty/retrieve.py/2023-06-21_23.52.31/ranking.tsv
# 0 Qual a maior característica da flora brasileira? 1512 1512 27.75323486328125 38724 1597.1758365631104 ms
# 1 Qual a maior característica da fauna brasileira? 1821 1821 28.342538833618164 38724 896.6647386550903 ms
# 2 Por que os países Guiana e Suriname não são filiados a Conmebol? 2349 2349 25.05866050720215 607542 661.2794399261475 ms
# 3 Por que a Bolívia tem duas capitais? 1510 1510 23.79318618774414 35040 543.5507893562317 ms
# 4 Qual o que significa decolonialidade? 659 659 29.7581844329834 414040 469.960355758667 ms
# 5 O que é sistema Swift? 1418 1418 27.964487075805664 381056 422.82597223917645 ms
# 6 Por que a seleção uruguaia ostenta 4 estrelas em seu escudo? 2606 2606 23.139629364013672 581110 390.76924324035645 ms
# 7 Qual a importância da Semana de Arte Moderna de 1922? 1709 1709 29.23712730407715 215836 359.3822121620178 ms
# 8 Por que Johann Sebastian Bach é considerado um revolucionário na história da música? 3036 3036 26.954452514648438 304651 335.68700154622394 ms
# 9 quais países europeus seguem o regime monarquista? 1612 1612 25.35076141357422 252335 315.52226543426514 ms
# 10 como é definido o pib de um país? 1351 1351 26.99901580810547 232183 298.9013411782005 ms
# 11 quais os critérios de definição dos monumentos intitulados maravilhas do mundo moderno? 3072 3072 24.69223403930664 310855 285.9779993693034 ms
# 12 por que paises escandinavos possuem bandeiras tão semelhantes? 1827 1827 24.936203002929688 132463 273.1795677771935 ms
# 13 Como o Brasil reagiu a epidemia de AIDS no fim do século XX? 3239 3239 24.897815704345703 629021 264.16613374437605 ms
# 14 Quais os riscos do uso de cigarros eletrônicos? 1418 1418 28.625823974609375 75695 255.46420415242514 ms
# 15 Qual a maior torcida de futebol do Brasil? 1137 1137 27.875221252441406 164906 247.48601019382477 ms
# 16 Qual foi a última grande seca no Nordeste brasileiro? 2015 2015 26.205387115478516 486599 240.18120765686035 ms
# 17 Quando se realizou o plebiscito popular para definir o sistema político do Brasil? 2418 2418 27.806659698486328 130271 235.053817431132 ms
# 18 Como idealizar uma nova constituição que seja mais realista que a nossa? 3058 3058 25.171886444091797 150920 230.85546493530273 ms
# 19 O que é uma constituição? 882 882 29.497909545898438 63010 225.35438537597656 ms
# 79 Quando começou a Virada Cultural em São Paulo? 2115 2115 27.543594360351562 576577 144.84913647174835 ms
# 80 O que fazer no final de semana em Vila Velha? 1296 1296 25.58319091796875 382407 144.44788297017416 ms
# 81 Em quais modalidades paraolímpicas o brasil tem melhor desempenho? 1769 1769 28.371206283569336 155748 144.0917079041644 ms
# 82 Quais os principais eventos esportivos no brasil? 1458 1458 27.170730590820312 619623 143.72760703764766 ms
# 83 Quantas vezes o voleibol feminino venceu o grand prix? 1451 1451 26.642223358154297 258062 143.58875865028017 ms
# 84 Qual é a principal cidade do basquete brasileiro? 1562 1562 25.25771141052246 482764 143.21946536793428 ms
# 85 Quais são as características de uma chapada? 1399 1399 27.263391494750977 529956 142.91174467219864 ms
# 86 Qual o relevo predominante do Brasil? 929 929 27.651676177978516 461743 142.49563217163086 ms
# 87 Quais as bacias hidrográficas mais importantes do Brasil? 1380 1380 29.18814468383789 199835 142.14198426766828 ms
# 88 O que foram as manifestações de 2013 no Brasil? 1970 1970 27.26154327392578 133232 141.8825588869245 ms
# 89 Processos de impeachment no Brasil 1289 1289 26.17003631591797 281147 141.52725007798938 ms
# 90 Processo de industrialização do Brasil 1436 1436 29.018875122070312 41054 141.2056068797688 ms
# 91 Quais são as regiões economicamente importantes no Brasil? 1425 1425 28.162240982055664 390116 140.89292287826538 ms
# 92 Roteiros para casais no sul do Brasil 1879 1879 27.397336959838867 252515 140.59666151641517 ms
# 93 Melhores praias do litoral potiguar 1091 1091 28.623807907104492 18589 140.2401974860658 ms
# 94 Quais são as cidades do Caminho da Fé? 1140 1140 27.301231384277344 381092 139.90627339011743 ms
# 95 É possível conhecer o Pico da Bandeira com crianças? 1906 1906 24.47978973388672 285219 139.63417460521063 ms
# 96 Esportes aquáticos no lago Paranoá 1851 1851 26.469829559326172 627172 139.34723863896636 ms
# 97 Quais os principais times do campeonato estadual Paranaense? 1433 1433 28.265169143676758 138051 139.0410345427844 ms
# 98 Qual o critério para classificação para a Copa do Brasil? 1516 1516 26.935375213623047 147522 138.75351289306025 ms
# 99 Quais são as principais religiões do Brasil? 854 854 29.98757553100586 598531 138.4101700782776 ms
# [Jun 21, 23:58:16] #> Logging query #0 (qid 0) now...
#
#
#
# /content/drive/MyDrive/unicamp/ia368v_dd/trabalho_final_UNICAMP-IR/ColBERT-X/experiments/dirty/retrieve.py/2023-06-21_23.52.31/ranking.tsv
# #> Done.

# %%
# !python3 -m xlmr_colbert.retrieve --similarity l2 --dim 48 --query_maxlen 32 \
	--index_root ../{CLUEWEB22_FOLDER} --index_name {CORPUS_PART_INDEX} --faiss_name ivfpq.262144.faiss --part-range 3..6 --log_scores \
	--retrieve_only --queries ../{QUERIES_FILE} \
	--amp --checkpoint ../colbertx_experiments/mMSMARCO-pt_048_dim/train.py/fine_tune_025/checkpoints/colbert-20000.dnn
# Out:
# 2023-06-21 23:59:09.611430: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-06-21 23:59:09.668330: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-21 23:59:10.921372: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
#
# [Jun 21, 23:59:22] #> Creating directory /content/drive/MyDrive/unicamp/ia368v_dd/trabalho_final_UNICAMP-IR/ColBERT-X/experiments/dirty/retrieve.py/2023-06-21_23.59.12
#
#
#
#
# [Jun 21, 23:59:26] #> Creating directory /content/drive/MyDrive/unicamp/ia368v_dd/trabalho_final_UNICAMP-IR/ColBERT-X/experiments/dirty/retrieve.py/2023-06-21_23.59.12/logs/
#
#
# [Jun 21, 23:59:27] {'root': 'experiments', 'experiment': 'dirty', 'run': '2023-06-21_23.59.12', 'rank': -1, 'similarity': 'l2', 'dim': 48, 'query_maxlen': 32, 'doc_maxlen': 180, 'mask_punctuation': False, 'checkpoint': '../colbertx_experiments/mMSMARCO-pt_048_dim/train.py/fine_tune_025/checkpoints/colbert-20000.dnn', 'bsize': 128, 'amp': True, 'queries': '../queries_validation.tsv', 'collection': None, 'qrels': None, 'index_root': '../clueweb22-pt_10M_sample', 'index_name': 'clueweb22-pt_10M_sample_part_00_index', 'partitions': None, 'nprobe': 10, 'retrieve_only': True, 'faiss_name': 'ivfpq.262144.faiss', 'faiss_depth': 1024, 'part_range': '3..6', 'batch': False, 'depth': 1000, 'log_scores': True}
#
# XLMRobertaConfig {
#   "_name_or_path": "xlm-roberta-large",
#   "architectures": [
#     "XLMRobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.30.2",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#
# Some weights of the model checkpoint at xlm-roberta-large were not used when initializing ColBERT: ['lm_head.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing ColBERT from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ColBERT from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ColBERT were not initialized from the model checkpoint at xlm-roberta-large and are newly initialized: ['linear.weight', 'roberta.embeddings.position_ids']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [Jun 21, 23:59:37] #> Loading model checkpoint.
# [Jun 21, 23:59:37] #> Loading checkpoint ../colbertx_experiments/mMSMARCO-pt_048_dim/train.py/fine_tune_025/checkpoints/colbert-20000.dnn ..
# [Jun 22, 00:00:17] #> checkpoint['epoch'] = 0
# [Jun 22, 00:00:17] #> checkpoint['batch'] = 20000
# [Jun 22, 00:00:17] [WARNING] 	 Got checkpoint['arguments']['doc_maxlen'] != args.doc_maxlen (i.e., 480 != 180)
# {
#     "root": "..\/colbertx_experiments\/",
#     "experiment": "mMSMARCO-pt_048_dim",
#     "run": "fine_tune_025",
#     "rank": -1,
#     "similarity": "l2",
#     "dim": 48,
#     "query_maxlen": 32,
#     "doc_maxlen": 480,
#     "mask_punctuation": false,
#     "resume": false,
#     "resume_optimizer": false,
#     "checkpoint": "..\/colbertx_experiments\/mMSMARCO-pt_048_dim\/train.py\/fine_tune_012\/checkpoints\/colbert-20000.dnn",
#     "lr": 3e-6,
#     "maxsteps": 20000,
#     "bsize": 12,
#     "accumsteps": 1,
#     "amp": true,
#     "base_model": "xlm-roberta-large",
#     "triples": "..\/mMARCO_triplets_025.tsv",
#     "queries": null,
#     "collection": null
# }
#
#
# [Jun 22, 00:00:17] #> Loading the queries from ../queries_validation.tsv ...
# [Jun 22, 00:00:18] #> Got 100 queries. All QIDs are unique.
#
# [Jun 22, 00:00:20] #> Loading the FAISS index from ../clueweb22-pt_10M_sample/clueweb22-pt_10M_sample_part_00_index/ivfpq.262144.faiss ..
# [Jun 22, 00:01:45] #> Building the emb2pid mapping..
# self.relative_range = range(629145, 1258290)
# [Jun 22, 00:01:59] len(self.emb2pid) = 580720308
# [Jun 22, 00:02:05] tensor.size() =  torch.Size([182837731, 48])
# [Jun 22, 00:02:05] |> Loading ../clueweb22-pt_10M_sample/clueweb22-pt_10M_sample_part_00_index/3.pt ...
# [Jun 22, 00:02:47] |> Loading ../clueweb22-pt_10M_sample/clueweb22-pt_10M_sample_part_00_index/4.pt ...
# [Jun 22, 00:04:51] |> Loading ../clueweb22-pt_10M_sample/clueweb22-pt_10M_sample_part_00_index/5.pt ...
# [Jun 22, 00:05:29] #> Using strides [402, 480]..
# [Jun 22, 00:05:30] #> Logging ranked lists to /content/drive/MyDrive/unicamp/ia368v_dd/trabalho_final_UNICAMP-IR/ColBERT-X/experiments/dirty/retrieve.py/2023-06-21_23.59.12/ranking.tsv
# 0 Qual a maior característica da flora brasileira? 1582 1582 28.117115020751953 1028331 1202.476978302002 ms
# 1 Qual a maior característica da fauna brasileira? 1763 1763 27.602554321289062 862109 658.4101915359497 ms
# 2 Por que os países Guiana e Suriname não são filiados a Conmebol? 2460 2460 25.959362030029297 1168196 479.0635903676351 ms
# 3 Por que a Bolívia tem duas capitais? 1592 1592 25.014162063598633 1044080 387.4266743659973 ms
# 4 Qual o que significa decolonialidade? 714 714 28.523157119750977 671835 330.7675361633301 ms
# 5 O que é sistema Swift? 1432 1432 28.094738006591797 758887 294.44154103597003 ms
# 6 Por que a seleção uruguaia ostenta 4 estrelas em seu escudo? 2688 2688 24.053268432617188 1018550 271.4295046670096 ms
# 7 Qual a importância da Semana de Arte Moderna de 1922? 1718 1718 29.328746795654297 974198 255.5197775363922 ms
# 8 Por que Johann Sebastian Bach é considerado um revolucionário na história da música? 2889 2889 25.787033081054688 688411 240.83672629462347 ms
# 9 quais países europeus seguem o regime monarquista? 1685 1685 26.319318771362305 691124 228.99727821350098 ms
# 10 como é definido o pib de um país? 1336 1336 28.15166664123535 712913 218.32921288230202 ms
# 11 quais os critérios de definição dos monumentos intitulados maravilhas do mundo moder
content/drive/MyDrive/unicamp/ia368v_dd/trabalho_final_UNICAMP-IR/ColBERT-X/experiments/dirty/retrieve.py/2023-06-21_23.59.12/ranking.tsv
# #> Done.

# %%
# !python3 -m xlmr_colbert.retrieve --similarity l2 --dim 48 --query_maxlen 32 \
	--index_root ../{CLUEWEB22_FOLDER} --index_name {CORPUS_PART_INDEX} --faiss_name ivfpq.262144.faiss --part-range 6..9 --log_scores \
	--retrieve_only --queries ../{QUERIES_FILE} \
	--amp --checkpoint ../colbertx_experiments/mMSMARCO-pt_048_dim/train.py/fine_tune_025/checkpoints/colbert-20000.dnn
# Out:
# 2023-06-22 00:06:14.301390: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-06-22 00:06:14.365721: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-22 00:06:15.686478: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
#
# [Jun 22, 00:06:27] #> Creating directory /content/drive/MyDrive/unicamp/ia368v_dd/trabalho_final_UNICAMP-IR/ColBERT-X/experiments/dirty/retrieve.py/2023-06-22_00.06.17
#
#
#
#
# [Jun 22, 00:06:31] #> Creating directory /content/drive/MyDrive/unicamp/ia368v_dd/trabalho_final_UNICAMP-IR/ColBERT-X/experiments/dirty/retrieve.py/2023-06-22_00.06.17/logs/
#
#
# [Jun 22, 00:06:31] {'root': 'experiments', 'experiment': 'dirty', 'run': '2023-06-22_00.06.17', 'rank': -1, 'similarity': 'l2', 'dim': 48, 'query_maxlen': 32, 'doc_maxlen': 180, 'mask_punctuation': False, 'checkpoint': '../colbertx_experiments/mMSMARCO-pt_048_dim/train.py/fine_tune_025/checkpoints/colbert-20000.dnn', 'bsize': 128, 'amp': True, 'queries': '../queries_validation.tsv', 'collection': None, 'qrels': None, 'index_root': '../clueweb22-pt_10M_sample', 'index_name': 'clueweb22-pt_10M_sample_part_00_index', 'partitions': None, 'nprobe': 10, 'retrieve_only': True, 'faiss_name': 'ivfpq.262144.faiss', 'faiss_depth': 1024, 'part_range': '6..9', 'batch': False, 'depth': 1000, 'log_scores': True}
#
# XLMRobertaConfig {
#   "_name_or_path": "xlm-roberta-large",
#   "architectures": [
#     "XLMRobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.30.2",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#
# Some weights of the model checkpoint at xlm-roberta-large were not used when initializing ColBERT: ['lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.dense.bias']
# - This IS expected if you are initializing ColBERT from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ColBERT from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ColBERT were not initialized from the model checkpoint at xlm-roberta-large and are newly initialized: ['roberta.embeddings.position_ids', 'linear.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [Jun 22, 00:06:43] #> Loading model checkpoint.
# [Jun 22, 00:06:43] #> Loading checkpoint ../colbertx_experiments/mMSMARCO-pt_048_dim/train.py/fine_tune_025/checkpoints/colbert-20000.dnn ..
# [Jun 22, 00:07:21] #> checkpoint['epoch'] = 0
# [Jun 22, 00:07:21] #> checkpoint['batch'] = 20000
# [Jun 22, 00:07:21] [WARNING] 	 Got checkpoint['arguments']['doc_maxlen'] != args.doc_maxlen (i.e., 480 != 180)
# {
#     "root": "..\/colbertx_experiments\/",
#     "experiment": "mMSMARCO-pt_048_dim",
#     "run": "fine_tune_025",
#     "rank": -1,
#     "similarity": "l2",
#     "dim": 48,
#     "query_maxlen": 32,
#     "doc_maxlen": 480,
#     "mask_punctuation": false,
#     "resume": false,
#     "resume_optimizer": false,
#     "checkpoint": "..\/colbertx_experiments\/mMSMARCO-pt_048_dim\/train.py\/fine_tune_012\/checkpoints\/colbert-20000.dnn",
#     "lr": 3e-6,
#     "maxsteps": 20000,
#     "bsize": 12,
#     "accumsteps": 1,
#     "amp": true,
#     "base_model": "xlm-roberta-large",
#     "triples": "..\/mMARCO_triplets_025.tsv",
#     "queries": null,
#     "collection": null
# }
#
#
# [Jun 22, 00:07:21] #> Loading the queries from ../queries_validation.tsv ...
# [Jun 22, 00:07:22] #> Got 100 queries. All QIDs are unique.
#
# [Jun 22, 00:07:23] #> Loading the FAISS index from ../clueweb22-pt_10M_sample/clueweb22-pt_10M_sample_part_00_index
# 83 Quantas vezes o voleibol feminino venceu o grand prix? 1604 1604 25.855510711669922 1351912 140.33355031694686 ms
# 84 Qual é a principal cidade do basquete brasileiro? 1861 1861 24.590896606445312 1548910 140.14731014476104 ms
# 85 Quais são as características de uma chapada? 1443 1443 27.429094314575195 1492636 139.8974712504897 ms
# 86 Qual o relevo predominante do Brasil? 1018 1018 29.39480209350586 1603431 139.64987349236148 ms
# 87 Quais as bacias hidrográficas mais importantes do Brasil? 1364 1364 28.10234832763672 1744935 139.32693546468562 ms
# 88 O que foram as manifestações de 2013 no Brasil? 2049 2049 27.713672637939453 1645743 139.0888396273838 ms
# 89 Processos de impeachment no Brasil 1318 1318 26.91126251220703 1506466 138.86547883351645 ms
# 90 Processo de industrialização do Brasil 1294 1294 29.095989227294922 1808174 138.64350580907129 ms
# 91 Quais são as regiões economicamente importantes no Brasil? 1414 1414 27.555810928344727 1859769 138.36206819700158 ms
# 92 Roteiros para casais no sul do Brasil 1730 1730 26.92546844482422 1782589 138.13680730840213 ms
# 93 Melhores praias do litoral potiguar 988 988 29.641450881958008 1447645 137.8301813247356 ms
# 94 Quais são as cidades do Caminho da Fé? 1211 1211 27.731931686401367 1347094 137.5775688572934 ms
# 95 É possível conhecer o Pico da Bandeira com crianças? 1796 1796 25.097156524658203 1777165 137.4372939268748 ms
# 96 Esportes aquáticos no lago Paranoá 1817 1817 26.58906364440918 1445027 137.23498767184228 ms
# 97 Quais os principais times do campeonato estadual Paranaense? 1481 1481 28.814477920532227 1580892 136.998074395316 ms
# 98 Qual o critério para classificação para a Copa do Brasil? 1667 1667 27.297183990478516 1768195 136.78317599826389 ms
# 99 Quais são as principais religiões do Brasil? 865 865 29.283472061157227 1824228 136.49425506591797 ms
# [Jun 22, 00:12:47] #> Logging query #0 (qid 0) now...
#
#
#
# /content/drive/MyDrive/unicamp/ia368v_dd/trabalho_final_UNICAMP-IR/ColBERT-X/experiments/dirty/retrieve.py/2023-06-22_00.06.17/ranking.tsv
# #> Done.

# %%
# !python3 -m xlmr_colbert.retrieve --similarity l2 --dim 48 --query_maxlen 32 \
	--index_root ../{CLUEWEB22_FOLDER} --index_name {CORPUS_PART_INDEX} --faiss_name ivfpq.262144.faiss --part-range 9..10 --log_scores \
	--retrieve_only --queries ../{QUERIES_FILE} \
	--amp --checkpoint ../colbertx_experiments/mMSMARCO-pt_048_dim/train.py/fine_tune_025/checkpoints/colbert-20000.dnn
# Out:
# 2023-06-22 00:13:17.836138: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-06-22 00:13:17.901327: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-22 00:13:19.187256: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
#
# [Jun 22, 00:13:29] #> Creating directory /content/drive/MyDrive/unicamp/ia368v_dd/trabalho_final_UNICAMP-IR/ColBERT-X/experiments/dirty/retrieve.py/2023-06-22_00.13.20
#
#
#
#
# [Jun 22, 00:13:33] #> Creating directory /content/drive/MyDrive/unicamp/ia368v_dd/trabalho_final_UNICAMP-IR/ColBERT-X/experiments/dirty/retrieve.py/2023-06-22_00.13.20/logs/
#
#
# [Jun 22, 00:13:34] {'root': 'experiments', 'experiment': 'dirty', 'run': '2023-06-22_00.13.20', 'rank': -1, 'similarity': 'l2', 'dim': 48, 'query_maxlen': 32, 'doc_maxlen': 180, 'mask_punctuation': False, 'checkpoint': '../colbertx_experiments/mMSMARCO-pt_048_dim/train.py/fine_tune_025/checkpoints/colbert-20000.dnn', 'bsize': 128, 'amp': True, 'queries': '../queries_validation.tsv', 'collection': None, 'qrels': None, 'index_root': '../clueweb22-pt_10M_sample', 'index_name': 'clueweb22-pt_10M_sample_part_00_index', 'partitions': None, 'nprobe': 10, 'retrieve_only': True, 'faiss_name': 'ivfpq.262144.faiss', 'faiss_depth': 1024, 'part_range': '9..10', 'batch': False, 'depth': 1000, 'log_scores': True}
#
# XLMRobertaConfig {
#   "_name_or_path": "xlm-roberta-large",
#   "architectures": [
#     "XLMRobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.30.2",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#
# Some weights of the model checkpoint at xlm-roberta-large were not used when initializing ColBERT: ['lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias']
# - This IS expected if you are initializing ColBERT from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ColBERT from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ColBERT were not initialized from the model checkpoint at xlm-roberta-large and are newly initialized: ['roberta.embeddings.position_ids', 'linear.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [Jun 22, 00:13:46] #> Loading model checkpoint.
# [Jun 22, 00:13:46] #> Loading checkpoint ../colbertx_experiments/mMSMARCO-pt_048_dim/train.py/fine_tune_025/checkpoints/colbert-20000.dnn ..
# [Jun 22, 00:14:24] #> checkpoint['epoch'] = 0
# [Jun 22, 00:14:24] #> checkpoint['batch'] = 20000
# [Jun 22, 00:14:24] [WARNING] 	 Got checkpoint['arguments']['doc_maxlen'] != args.doc_maxlen (i.e., 480 != 180)
# {
#     "root": "..\/colbertx_experiments\/",
#     "experiment": "mMSMARCO-pt_048_dim",
#     "run": "fine_tune_025",
#     "rank": -1,
#     "similarity": "l2",
#     "dim": 48,
#     "query_maxlen": 32,
#     "doc_maxlen": 480,
#     "mask_punctuation": false,
#     "resume": false,
#     "resume_optimizer": false,
#     "checkpoint": "..\/colbertx_experiments\/mMSMARCO-pt_048_dim\/train.py\/fine_tune_012\/checkpoints\/colbert-20000.dnn",
#     "lr": 3e-6,
#     "maxsteps": 20000,
#     "bsize": 12,
#     "accumsteps": 1,
#     "amp": true,
#     "base_model": "xlm-roberta-large",
#     "triples": "..\/mMARCO_triplets_025.tsv",
#     "queries": null,
#     "collection": null
# }
#
#
# [Jun 22, 00:14:24] #> Loading the queries from ../queries_validation.tsv ...
# [Jun 22, 00:14:24] #> Got 100 queries. All QIDs are unique.
#
# [Jun 22, 00:14:26] #> Loading the FAISS index from ../clueweb22-pt_10M_sample/clueweb22-pt_10M_sample_part_00_index/ivfpq.262144.faiss ..
# [Jun 22, 00:15:57] #> Building the emb2pid mapping..
# self.relative_range = range(1887435, 2000000)
# [Jun 22, 00:16:09] len(self.emb2pid) = 580720308
# [Jun 22, 00:16:14] tensor.size() =  torch.Size([32745295, 48])
# [Jun 22, 00:16:14] |> Loading ../clueweb22-pt_10M_sample/clueweb22-pt_10M_sample_part_00_index/9.pt ...
# [Jun 22, 00:16:47] #> Using strides [400, 480]..
# [Jun 22, 00:16:48] #> Logging ranked lists to /content/drive/MyDrive/unicamp/ia368v_dd/trabalho_final_UNICAMP-IR/ColBERT-X/experiments/dirty/retrieve.py/2023-06-22_00.13.20/ranking.tsv
# 0 Qual a maior característica da flora brasileira? 277 277 27.368877410888672 1908934 1198.479175567627 ms
# 1 Qual a maior característica da fauna brasileira? 322 322 26.55950927734375 1908934 652.3691415786743 ms
# 2 Por que os países Guiana e Suriname não são filiados a Conmebol? 438 438 23.148677825927734 1902521 471.8434810638428 ms
# 3 Por que a Bolívia tem duas capitais? 280 280 23.454788208007812 1943074 381.4946413040161 ms
# 4 Qual o que significa decolonialidade? 129 129 27.993682861328125 1896690 330.81607818603516 ms
# 5 O que é sistema Swift? 227 227 27.349212646484375 1899567 293.7607367833455 ms
# 6 Por que a seleção uruguaia ostenta 4 estrelas em seu escudo? 508 508 22.907339096069336 1956876 267.1526159558977 ms
# 7 Qual a importância da Semana de Arte Moderna de 1922? 339 339 29.09914779663086 1975889 246.6655969619751 ms
# 8 Por que Johann Sebastian Bach é considerado um revolucionário na história da música? 583 583 23.890871047973633 1943720 230.74883884853787 ms
# 9 quais países europeus seguem o regime monarquista? 292 292 25.03768539428711 1969552 218.08056831359863 ms
# 10 como é definido o pib de um país? 233 233 26.668655395507812 1926674 207.3980461467396 ms
# 11 quais os critérios de definição dos monumentos intitulados maravilhas do mundo moder